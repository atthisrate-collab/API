# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import matplotlib.pyplot as plt  # 한글 폰트 깨짐 방지
plt.rcParams['font.family'] = 'Malgun Gothic'


df = sns.load_dataset('titanic')
print(df.head())
print(df.shape)
print(df.info())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# (891, 15)
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
mis = df.isnull().sum()
total = len(df)

mis_percent = (mis / total) * 100
print(mis_percent)

print(pd.DataFrame({'결측수': mis, '결측비': mis_percent})[mis>0])
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64
#              결측수        결측비
# age          177  19.865320
# embarked       2   0.224467
# deck         688  77.216611
# embark_town    2   0.224467

# %%
# 결측치 채우기
# df = df.drop(columns=['deck'])
# df['embarked'] =df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
# df['age'] = df['age'].fillna(df['age'].median(), inplace=True)
# df['embark_town'] =df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
corr = df[['survived','pclass','age','fare','sibsp','parch']].corr()
corr['survived'].sort_values(ascending=False)
# Out:
# survived    1.000000
# fare        0.257307
# parch       0.081629
# sibsp      -0.035322
# age        -0.064910
# pclass     -0.338481
# Name: survived, dtype: float64

# %%
df.describe().round(2)
# Out:
#        survived  pclass     age   sibsp   parch    fare
# count    891.00  891.00  891.00  891.00  891.00  891.00
# mean       0.38    2.31   29.36    0.52    0.38   32.20
# std        0.49    0.84   13.02    1.10    0.81   49.69
# min        0.00    1.00    0.42    0.00    0.00    0.00
# 25%        0.00    2.00   22.00    0.00    0.00    7.91
# 50%        0.00    3.00   28.00    0.00    0.00   14.45
# 75%        1.00    3.00   35.00    1.00    0.00   31.00
# max        1.00    3.00   80.00    8.00    6.00  512.33

# %%
# Fiure와 서브플롯 생성

# 생존여부 분포
fig, axes = plt.subplots(2, 3)

df['survived'].value_counts().rename({0:'사망', 1:'생존'}).plot(kind='bar', ax=axes[0,0],rot=0)
axes[0,0].set_title('생존 대 사망')

# 객실 등급별 생존율
df.groupby('pclass')['survived'].mean().plot(kind='bar', ax=axes[0,1],rot=0)
axes[0,1].set_title('객실 등급별 생존률')

# 성별 생존률
df.groupby('sex')['survived'].mean().plot(kind='bar', ax=axes[0,2],rot=0)
axes[0,2].set_title('성별 생존률')

# 나이 분포 (생존/사망)
# for s, color, label in [(0,'#e74c3c','사망'), (1,'#2ecc71','생존')]:
#     df[df['survived']==s]['age'].hist(
#         ax=axes[1,0], alpha=0.6, color=color, label=label, bins=20)

for s, color, label in [(0, '#e74c3c', '사망'), (1, '#2ecc71', '생존')]:
    df[df['survived']==s]['age'].hist(ax=axes[1,0], alpha=0.6, color=color, label=label, bins=20)
    axes[1,0].set_title('나이 분포 (생존/사망)')
    axes[1,0].legend()


# 요금 분포

# sns.boxplot(data='titanic',x='survived', y='fare', ax=axes=[1,1],  palette='Set2')


# 레이아웃 조정
plt.tight_layout()
plt.show()
